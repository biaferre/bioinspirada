# %% [markdown]
# <a href="https://colab.research.google.com/github/biaferre/bioinspirada/blob/main/8_Rainhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Implementação Base

# %% [markdown]
# ### Definição de parâmetros

# %%
import random

N = 8
start_mutation_rate = 0.4
start_crossover_rate = 0.9
start_population_size = 5
start_generations_max = 100

# %% [markdown]
# ### Funções auxiliares
# Aqui temos
#
#
# *   Geração de indivíduos pra população inicial
# *   Avaliação de fitness
# *   Seleção de pais por torneio
# *   Recombinação cut e crossfill
# *   Mutação por troca de gene

# %%
def generate_individual():
    return random.sample(range(N), N)

def fitness(individual):
    non_attacking = 28
    for i in range(N):
        for j in range(i + 1, N):
            if abs(individual[i] - individual[j]) == abs(i - j):
                non_attacking -= 1
    return non_attacking

def tournament_selection(population, k=5):
    return max(random.sample(population, k), key=fitness)

def cut_and_crossfill(parent1, parent2, crossover_rate):
    if random.random() < crossover_rate:
      cut = random.randint(1, N - 1)
      child1 = parent1[:cut]
      child2 = parent2[:cut]

      fill1 = [gene for gene in parent2 if gene not in child1]
      fill2 = [gene for gene in parent1 if gene not in child2]

      return child1 + fill1, child2 + fill2

    else:
      return parent1, parent2

def mutate(individual, mutation_rate):
    if random.random() < mutation_rate:
        i, j = random.sample(range(N), 2)
        individual[i], individual[j] = individual[j], individual[i]

# %% [markdown]
# ### Algoritmo Genético em execução

# %%
def genetic_algorithm(population_size, generations_max, crossover_rate, mutation_rate):
    population = [generate_individual() for _ in range(population_size)]
    for generation in range(generations_max):
        offspring = []
        while len(offspring) < population_size:
            parent1 = tournament_selection(population)
            parent2 = tournament_selection(population)
            child1, child2 = cut_and_crossfill(parent1, parent2, crossover_rate)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            offspring.extend([child1, child2])

        combined_population = population + offspring
        combined_population.sort(key=fitness, reverse=True)
        population = combined_population[:population_size]

        if fitness(population[0]) == 28:
            print(f"Solução encontrada na geração {generation}: {population[0]}")
            return population[0]

    print("Melhor solução encontrada:", population[0])
    return population[0]

    print("Melhor solução encontrada:", population[0])
    return population[0]

solution = genetic_algorithm(start_population_size, start_generations_max, start_crossover_rate, start_mutation_rate)
# Out:
# Melhor solução encontrada: [5, 0, 2, 6, 3, 1, 7, 4]

# %% [markdown]
# Visualizando o tabuleiro:

# %%
if solution:
    board = [["." for _ in range(N)] for _ in range(N)]
    for col, row in enumerate(solution):
      board[row][col] = "Q"
    print("\nTabuleiro Final:")
    for row in board:
      print(" ".join(row))
# Out:
# Tabuleiro Final:
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .

# %% [markdown]
# ## Melhorias & Análise
# Para explorar possíveis melhorias no algoritmo, podemos atacar por frentes diferentes:
#
# * Taxas de mutação e recombinação
# * Tamanho da população
# * Método de seleção de pais
# * Método de seleção de sobreviventes

# %% [markdown]
# Vamos usar os seguintes critérios de análise:
#
# 1. Execuções necessárias pra convergir
# 2. Média e desvio padrão
# 3. Nº de indivíduos que convergiram por execução
# 4. Fitness médio x Fitness mais alto por execução
# 5. Fitness médio total
#
# Editando o código pra incluir esses critérios:

# %%
def genetic_algorithm(population_size, generations_max, crossover_rate, mutation_rate):
    population = [generate_individual() for _ in range(population_size)]
    result = {}
    for generation in range(generations_max):
        offspring = []
        while len(offspring) < population_size:
            parent1 = tournament_selection(population)
            parent2 = tournament_selection(population)
            child1, child2 = cut_and_crossfill(parent1, parent2, crossover_rate)
            mutate(child1, mutation_rate)
            mutate(child2, mutation_rate)
            offspring.extend([child1, child2])

        combined_population = population + offspring
        combined_population.sort(key=fitness, reverse=True)
        population = combined_population[:population_size]

        if fitness(population[0]) == 28:
            print(f"Solução encontrada na geração {generation}: {population[0]}")
            result = {
                "solution": population[0],
                "generations": generation,
                "fitness": fitness(population[0]),
                "converged": True
            }
            return result

    result = {
          "solution": population[0],
          "generations": generations_max,
          "fitness": fitness(population[0]),
          "converged": False
    }

    return result

# %%
import statistics
import pandas as pd
from collections import defaultdict

def run_experiments():
    mutation_rates = [0.0001, 0.001, 0.1, 0.3, 0.5]
    crossover_rates = [0.001, 0.1, 0.6, 0.8, 0.9]
    population_sizes = [10, 20, 50, 100, 200]
    generations_max = 1000
    runs_per_config = 10

    results = []

    all_data = []

    for pop_size in population_sizes:
        for mut_rate in mutation_rates:
            for cross_rate in crossover_rates:
                fitnesses = []
                generations = []
                converged_count = 0

                for _ in range(runs_per_config):
                    result = genetic_algorithm(
                        pop_size, generations_max, cross_rate, mut_rate
                    )
                    fitnesses.append(result["fitness"])
                    generations.append(result["generations"])
                    if result["converged"]:
                        converged_count += 1

                config = {
                    "population": pop_size,
                    "mutation_rate": mut_rate,
                    "crossover_rate": cross_rate,
                    "avg_fitness": statistics.mean(fitnesses),
                    "std_fitness": statistics.stdev(fitnesses),
                    "avg_generations": statistics.mean(generations),
                    "convergence_rate": converged_count / runs_per_config,
                    "fitnesses": fitnesses,
                    "generations": generations
                }

                results.append(config)
                all_data.append(config)

    df = pd.DataFrame(all_data)
    top5 = df.sort_values(by=["avg_fitness", "convergence_rate"], ascending=[False, False]).head(5)

    for i, r in top5.iterrows():
        print(f"Pop: {r['population']}, Mut: {r['mutation_rate']}, Cross: {r['crossover_rate']} | "
              f"Fitness: {r['avg_fitness']:.2f} ± {r['std_fitness']:.2f} | "
              f"Gens: {r['avg_generations']:.2f} | Conv: {int(r['convergence_rate'] * 100)}%")

# %%
run_experiments()
# Out:
# Solução encontrada na geração 23: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 0: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 0: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 1: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 854: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 151: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 1: [7, 3, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 854: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 408: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 34: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 669: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 682: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 55: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 286: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 847: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 696: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 246: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 991: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 120: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 30: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 314: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 85: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 172: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 340: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 360: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 659: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 214: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 56: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 66: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 45: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 313: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 4: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 52: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 22: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 2: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 47: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 190: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 7: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 0: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 1: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 23: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 68: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 66: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 365: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 433: [3, 7, 4, 2, 0, 6, 1, 5]
# Solução encontrada na geração 85: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 227: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 39: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 846: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 455: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 315: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 526: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 6: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 681: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 1: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 141: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 20: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 153: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 744: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 613: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 398: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 190: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 45: [0, 6, 3, 5, 7, 1, 4, 2]
# Solução encontrada na geração 381: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 166: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 240: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 358: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 497: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 137: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 97: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 201: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 136: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 403: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 99: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 40: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 197: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 8: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 13: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 0: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 168: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 86: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 2: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 72: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 16: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 16: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 274: [4, 6, 1, 5, 2, 0, 7, 3]
# Solução encontrada na geração 266: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 24: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 20: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 173: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 117: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 209: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 264: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 3: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 134: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 1: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 124: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 0: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 117: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 13: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 2: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 190: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 3: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 839: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 835: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 665: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 758: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 113: [3, 0, 4, 7, 5, 2, 6, 1]
# Solução encontrada na geração 584: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 841: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 82: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 591: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 401: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 95: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 96: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 313: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 63: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 32: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 72: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 50: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 50: [0, 6, 4, 7, 1, 3, 5, 2]
# Solução encontrada na geração 130: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 104: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 6: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 140: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 6: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 69: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 15: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 15: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 4: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 16: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 1: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 3: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 5: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 11: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 31: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 212: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 65: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 4: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 8: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 78: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 40: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 5: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 3: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 48: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 297: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 124: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 50: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 2: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 13: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 69: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 2: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 128: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 640: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 300: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 0: [0, 6, 3, 5, 7, 1, 4, 2]
# Solução encontrada na geração 1: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 259: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 205: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 25: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 0: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 366: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 116: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 202: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 766: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 0: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 458: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 294: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 0: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 493: [3, 5, 7, 1, 6, 0, 2, 4]
# Solução encontrada na geração 0: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 0: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 0: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 0: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 49: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 586: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 155: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 248: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 356: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 269: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 39: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 620: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 330: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 398: [7, 1, 4, 2, 0, 6, 3, 5]
# Solução encontrada na geração 12: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 73: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 637: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 285: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 10: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 192: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 17: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 267: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 67: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 297: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 268: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 49: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 3: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 95: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 56: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 10: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 103: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 53: [3, 7, 4, 2, 0, 6, 1, 5]
# Solução encontrada na geração 1: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 108: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 43: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 4: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 47: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 5: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 36: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 18: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 347: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 453: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 1: [3, 7, 4, 2, 0, 6, 1, 5]
# Solução encontrada na geração 856: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 0: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 180: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 0: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 350: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 1: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 117: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 254: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 334: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 5: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 2: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 824: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 14: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 274: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 421: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 151: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 26: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 148: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 816: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 303: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 163: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 241: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 22: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 163: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 59: [4, 6, 1, 5, 2, 0, 7, 3]
# Solução encontrada na geração 21: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 6: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 169: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 43: [3, 5, 7, 1, 6, 0, 2, 4]
# Solução encontrada na geração 10: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 22: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 14: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 80: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 77: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 11: [0, 6, 3, 5, 7, 1, 4, 2]
# Solução encontrada na geração 58: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 4: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 94: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 11: [4, 6, 1, 5, 2, 0, 7, 3]
# Solução encontrada na geração 10: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 2: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 4: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 37: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 2: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 7: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 383: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 1: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 40: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 2: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 1: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 2: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 247: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 15: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 219: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 87: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 13: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 2: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 74: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 5: [4, 1, 3, 5, 7, 2, 0, 6]
# Solução encontrada na geração 145: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 340: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 229: [3, 1, 6, 2, 5, 7, 4, 0]
# Solução encontrada na geração 826: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 162: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 284: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 249: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 34: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 67: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 571: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 126: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 21: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 10: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 1: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 173: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 36: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 4: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 86: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 20: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 5: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 34: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 6: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 2: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 5: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 9: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 5: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 1: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 0: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 1: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 52: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 47: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 3: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 15: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 4: [7, 1, 4, 2, 0, 6, 3, 5]
# Solução encontrada na geração 14: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 35: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 2: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 3: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 3: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 5: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 4: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 66: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 3: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 22: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 101: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 0: [7, 1, 3, 0, 6, 4, 2, 5]
# Solução encontrada na geração 1: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 3: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 115: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 5: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 0: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 0: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 1: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 0: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 0: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 1: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 1: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 2: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 3: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 2: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 42: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 1: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 1: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 1: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 8: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 42: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 2: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 3: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 547: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 1: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 668: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 0: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 718: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 2: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 390: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 671: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 1: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 13: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 583: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 1: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 22: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 2: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 180: [3, 7, 0, 4, 6, 1, 5, 2]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 567: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 1: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 0: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 1: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 0: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 144: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 0: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 2: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 2: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 2: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 765: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 228: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 40: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 591: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 70: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 340: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 296: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 179: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 836: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 52: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 43: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 0: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 46: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 0: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 4: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 36: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 0: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 28: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 21: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 105: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 0: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 4: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 35: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 214: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 2: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 2: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 2: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 2: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 10: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 0: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 3: [0, 6, 4, 7, 1, 3, 5, 2]
# Solução encontrada na geração 3: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 0: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 14: [3, 5, 7, 1, 6, 0, 2, 4]
# Solução encontrada na geração 131: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 2: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 6: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 18: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 0: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 0: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 0: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 0: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 37: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 1: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 0: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 1: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 439: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 3: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 6: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 182: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 0: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 265: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 527: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 4: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 327: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 336: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 607: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 28: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 878: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 16: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 30: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 14: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 37: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 57: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 54: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 124: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 4: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 18: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 7: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 0: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 5: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 38: [3, 5, 7, 1, 6, 0, 2, 4]
# Solução encontrada na geração 7: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 5: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 3: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 3: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 34: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 3: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 33: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 0: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 5: [4, 6, 1, 5, 2, 0, 7, 3]
# Solução encontrada na geração 0: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 26: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 2: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 0: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 1: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 1: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 1: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 0: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 3: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 0: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 2: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 8: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 1: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 3: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 5: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 11: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 0: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 615: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 0: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 406: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 106: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 61: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 718: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 148: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 5: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 11: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 16: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 139: [7, 3, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 1: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 4: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 68: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 75: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 38: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 22: [3, 1, 6, 2, 5, 7, 4, 0]
# Solução encontrada na geração 9: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 4: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 1: [3, 0, 4, 7, 5, 2, 6, 1]
# Solução encontrada na geração 4: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 6: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 2: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 2: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 15: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 0: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 9: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 1: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 1: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 4: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 0: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 3: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 3: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 25: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 2: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 13: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 0: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 2: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 4: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 3: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 1: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 0: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 3: [6, 0, 2, 7, 5, 3, 1, 4]
# Solução encontrada na geração 1: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 13: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 1: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 1: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 0: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 0: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 0: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 205: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 0: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 2: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 0: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 208: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 9: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 0: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 1: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 1: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 2: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 0: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 272: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 4: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 8: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 0: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 1: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 1: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 1: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 0: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 0: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 0: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 1: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 0: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 2: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 0: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 2: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 10: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 0: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 0: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 4: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 7: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 117: [4, 6, 1, 5, 2, 0, 7, 3]
# Solução encontrada na geração 0: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 352: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 0: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 0: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 250: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 0: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 10: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 0: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 534: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 449: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 5: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 0: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 2: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 0: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 1: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 0: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 0: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 1: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 5: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 0: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 0: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 1: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 0: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 1: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 1: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 2: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 2: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 2: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 12: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 1: [6, 0, 2, 7, 5, 3, 1, 4]
# Solução encontrada na geração 100: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 4: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 2: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 4: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 0: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 25: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 3: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 0: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 153: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 253: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 314: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 692: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 131: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 0: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 2: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 361: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 0: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 18: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 6: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 0: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 4: [4, 6, 1, 5, 2, 0, 7, 3]
# Solução encontrada na geração 12: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 5: [0, 6, 4, 7, 1, 3, 5, 2]
# Solução encontrada na geração 6: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 0: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 1: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 0: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 4: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 0: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 1: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 0: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 0: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 0: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 2: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 2: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 0: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 3: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 0: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 17: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 3: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 0: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 0: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 2: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 73: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 0: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 4: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 1: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 1: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 0: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 0: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 0: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 2: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 0: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 1: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 0: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 189: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 298: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 88: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 285: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 325: [3, 0, 4, 7, 5, 2, 6, 1]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 169: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 184: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 696: [7, 3, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 428: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 2: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 54: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 9: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 1: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 3: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 1: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 0: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 7: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 6: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 9: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 1: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 8: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 5: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 2: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 6: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 2: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 2: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 0: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 0: [5, 3, 6, 0, 2, 4, 1, 7]
# Solução encontrada na geração 0: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 1: [7, 1, 3, 0, 6, 4, 2, 5]
# Solução encontrada na geração 0: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 0: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 2: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 2: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 1: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 9: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 2: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 0: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 0: [3, 7, 4, 2, 0, 6, 1, 5]
# Solução encontrada na geração 0: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 2: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 1: [3, 7, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 5: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 0: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 2: [2, 5, 7, 1, 3, 0, 6, 4]
# Solução encontrada na geração 2: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 1: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 1: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 270: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 24: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 450: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 424: [3, 7, 4, 2, 0, 6, 1, 5]
# Solução encontrada na geração 861: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 394: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 110: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 20: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 0: [3, 1, 7, 5, 0, 2, 4, 6]
# Solução encontrada na geração 6: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 5: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 0: [6, 0, 2, 7, 5, 3, 1, 4]
# Solução encontrada na geração 3: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 0: [4, 1, 3, 5, 7, 2, 0, 6]
# Solução encontrada na geração 15: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 68: [4, 6, 1, 3, 7, 0, 2, 5]
# Solução encontrada na geração 7: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 15: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 2: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 0: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 1: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 1: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 1: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 7: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 1: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 0: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 1: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 1: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 2: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 2: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 2: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 1: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 0: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 0: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 1: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 0: [3, 7, 4, 2, 0, 6, 1, 5]
# Solução encontrada na geração 1: [3, 5, 7, 1, 6, 0, 2, 4]
# Solução encontrada na geração 0: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 0: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 0: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 1: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 0: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 0: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 5: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 2: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 1: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 1: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 0: [7, 3, 0, 2, 5, 1, 6, 4]
# Solução encontrada na geração 0: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 308: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 32: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 0: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 0: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 0: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 0: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 0: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 3: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 62: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 0: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 0: [4, 1, 3, 5, 7, 2, 0, 6]
# Solução encontrada na geração 555: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 0: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 0: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 1: [4, 1, 3, 5, 7, 2, 0, 6]
# Solução encontrada na geração 0: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 0: [0, 6, 3, 5, 7, 1, 4, 2]
# Solução encontrada na geração 1: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 0: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 0: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 0: [3, 1, 6, 2, 5, 7, 0, 4]
# Solução encontrada na geração 0: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 0: [6, 0, 2, 7, 5, 3, 1, 4]
# Solução encontrada na geração 0: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 0: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 1: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 0: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 0: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 0: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 2: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 0: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 1: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 2: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 0: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 10: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 0: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 1: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 0: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 0: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 0: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 0: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 0: [0, 4, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 0: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 0: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 7: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 0: [3, 1, 4, 7, 5, 0, 2, 6]
# Solução encontrada na geração 0: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 422: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 1: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 1: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 4: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 1: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 42: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 0: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 14: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 0: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 50: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 0: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 0: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 0: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 3: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 2: [7, 1, 4, 2, 0, 6, 3, 5]
# Solução encontrada na geração 5: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 1: [3, 5, 7, 1, 6, 0, 2, 4]
# Solução encontrada na geração 2: [4, 2, 0, 5, 7, 1, 3, 6]
# Solução encontrada na geração 0: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 1: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 33: [6, 0, 2, 7, 5, 3, 1, 4]
# Solução encontrada na geração 1: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 0: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 0: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 0: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 0: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 0: [0, 6, 3, 5, 7, 1, 4, 2]
# Solução encontrada na geração 0: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 0: [1, 4, 6, 3, 0, 7, 5, 2]
# Solução encontrada na geração 0: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 1: [4, 7, 3, 0, 6, 1, 5, 2]
# Solução encontrada na geração 1: [2, 5, 3, 1, 7, 4, 6, 0]
# Solução encontrada na geração 0: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 0: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 1: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 946: [1, 5, 7, 2, 0, 3, 6, 4]
# Solução encontrada na geração 0: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 0: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 720: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 151: [6, 1, 3, 0, 7, 4, 2, 5]
# Solução encontrada na geração 41: [1, 4, 6, 0, 2, 7, 5, 3]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 695: [1, 7, 5, 0, 2, 4, 6, 3]
# Solução encontrada na geração 3: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 2: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 0: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 3: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 0: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 1: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 5: [4, 0, 7, 5, 2, 6, 1, 3]
# Solução encontrada na geração 2: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 0: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 0: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 4: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 0: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 0: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 1: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 2: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 0: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 0: [5, 1, 6, 0, 2, 4, 7, 3]
# Solução encontrada na geração 2: [7, 1, 4, 2, 0, 6, 3, 5]
# Solução encontrada na geração 0: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 1: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 0: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 3: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 0: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 0: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 0: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 1: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 0: [4, 0, 7, 3, 1, 6, 2, 5]
# Solução encontrada na geração 1: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 0: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 0: [5, 3, 0, 4, 7, 1, 6, 2]
# Solução encontrada na geração 0: [4, 1, 3, 5, 7, 2, 0, 6]
# Solução encontrada na geração 1: [4, 1, 7, 0, 3, 6, 2, 5]
# Solução encontrada na geração 0: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 0: [0, 6, 4, 7, 1, 3, 5, 2]
# Solução encontrada na geração 0: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 1: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 517: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 249: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 211: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 4: [1, 5, 0, 6, 3, 7, 2, 4]
# Solução encontrada na geração 388: [4, 6, 3, 0, 2, 7, 5, 1]
# Solução encontrada na geração 0: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 257: [6, 4, 2, 0, 5, 7, 1, 3]
# Solução encontrada na geração 167: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 518: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 8: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 7: [4, 6, 0, 3, 1, 7, 5, 2]
# Solução encontrada na geração 1: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 2: [3, 1, 6, 4, 0, 7, 5, 2]
# Solução encontrada na geração 2: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 12: [5, 2, 4, 7, 0, 3, 1, 6]
# Solução encontrada na geração 0: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 2: [3, 0, 4, 7, 1, 6, 2, 5]
# Solução encontrada na geração 0: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 8: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 2: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 1: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 5: [6, 3, 1, 7, 5, 0, 2, 4]
# Solução encontrada na geração 1: [6, 3, 1, 4, 7, 0, 2, 5]
# Solução encontrada na geração 1: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 1: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 0: [2, 5, 1, 6, 0, 3, 7, 4]
# Solução encontrada na geração 0: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 0: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 0: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 4: [1, 6, 2, 5, 7, 4, 0, 3]
# Solução encontrada na geração 0: [2, 6, 1, 7, 5, 3, 0, 4]
# Solução encontrada na geração 0: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 2: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 0: [5, 2, 6, 1, 3, 7, 0, 4]
# Solução encontrada na geração 0: [0, 5, 7, 2, 6, 3, 1, 4]
# Solução encontrada na geração 1: [4, 6, 0, 2, 7, 5, 3, 1]
# Solução encontrada na geração 0: [3, 6, 0, 7, 4, 1, 5, 2]
# Solução encontrada na geração 0: [5, 2, 4, 6, 0, 3, 1, 7]
# Solução encontrada na geração 1: [2, 5, 3, 0, 7, 4, 6, 1]
# Solução encontrada na geração 0: [3, 6, 4, 1, 5, 0, 2, 7]
# Solução encontrada na geração 0: [5, 7, 1, 3, 0, 6, 4, 2]
# Solução encontrada na geração 1: [5, 3, 6, 0, 7, 1, 4, 2]
# Solução encontrada na geração 0: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 0: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 0: [5, 1, 6, 0, 3, 7, 4, 2]
# Solução encontrada na geração 1: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 0: [5, 3, 1, 7, 4, 6, 0, 2]
# Solução encontrada na geração 420: [2, 5, 7, 0, 4, 6, 1, 3]
# Solução encontrada na geração 1: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 251: [3, 6, 2, 7, 1, 4, 0, 5]
# Solução encontrada na geração 138: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 41: [6, 2, 0, 5, 7, 4, 1, 3]
# Solução encontrada na geração 262: [4, 2, 7, 3, 6, 0, 5, 1]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 1: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 415: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 735: [2, 5, 1, 4, 7, 0, 6, 3]
# Solução encontrada na geração 14: [5, 2, 0, 7, 4, 1, 3, 6]
# Solução encontrada na geração 0: [2, 4, 1, 7, 0, 6, 3, 5]
# Solução encontrada na geração 1: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 0: [4, 6, 1, 5, 2, 0, 3, 7]
# Solução encontrada na geração 0: [4, 2, 0, 6, 1, 7, 5, 3]
# Solução encontrada na geração 1: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 8: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 3: [6, 1, 5, 2, 0, 3, 7, 4]
# Solução encontrada na geração 1: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 1: [2, 7, 3, 6, 0, 5, 1, 4]
# Solução encontrada na geração 1: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 0: [3, 6, 4, 2, 0, 5, 7, 1]
# Solução encontrada na geração 0: [4, 1, 3, 5, 7, 2, 0, 6]
# Solução encontrada na geração 0: [5, 2, 0, 6, 4, 7, 1, 3]
# Solução encontrada na geração 1: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 0: [2, 0, 6, 4, 7, 1, 3, 5]
# Solução encontrada na geração 0: [2, 4, 1, 7, 5, 3, 6, 0]
# Solução encontrada na geração 0: [0, 6, 4, 7, 1, 3, 5, 2]
# Solução encontrada na geração 0: [5, 2, 6, 1, 7, 4, 0, 3]
# Solução encontrada na geração 0: [4, 1, 5, 0, 6, 3, 7, 2]
# Solução encontrada na geração 1: [4, 1, 3, 6, 2, 7, 5, 0]
# Solução encontrada na geração 0: [4, 0, 3, 5, 7, 1, 6, 2]
# Solução encontrada na geração 1: [1, 6, 4, 7, 0, 3, 5, 2]
# Solução encontrada na geração 2: [5, 2, 0, 7, 3, 1, 6, 4]
# Solução encontrada na geração 0: [2, 4, 7, 3, 0, 6, 1, 5]
# Solução encontrada na geração 0: [5, 2, 6, 3, 0, 7, 1, 4]
# Solução encontrada na geração 0: [2, 5, 1, 6, 4, 0, 7, 3]
# Solução encontrada na geração 1: [3, 5, 7, 2, 0, 6, 4, 1]
# Solução encontrada na geração 0: [5, 0, 4, 1, 7, 2, 6, 3]
# Solução encontrada na geração 1: [1, 3, 5, 7, 2, 0, 6, 4]
# Solução encontrada na geração 0: [2, 5, 7, 0, 3, 6, 4, 1]
# Solução encontrada na geração 1: [7, 1, 3, 0, 6, 4, 2, 5]
# Solução encontrada na geração 0: [6, 2, 7, 1, 4, 0, 5, 3]
# Solução encontrada na geração 0: [7, 2, 0, 5, 1, 4, 6, 3]
# Solução encontrada na geração 0: [2, 6, 1, 7, 4, 0, 3, 5]
# Solução encontrada na geração 0: [3, 5, 0, 4, 1, 7, 2, 6]
# Solução encontrada na geração 1: [4, 7, 3, 0, 2, 5, 1, 6]
# Solução encontrada na geração 0: [2, 4, 6, 0, 3, 1, 7, 5]
# Solução encontrada na geração 0: [3, 1, 7, 4, 6, 0, 2, 5]
# Solução encontrada na geração 0: [4, 7, 3, 0, 6, 1, 5, 2]
# Pop: 10, Mut: 0.1, Cross: 0.6 | Fitness: 28.00 ± 0.00 | Gens: 79.70 | Conv: 100%
# Pop: 10, Mut: 0.3, Cross: 0.001 | Fitness: 28.00 ± 0.00 | Gens: 285.10 | Conv: 100%
# Pop: 10, Mut: 0.3, Cross: 0.1 | Fitness: 28.00 ± 0.00 | Gens: 220.80 | Conv: 100%
# Pop: 10, Mut: 0.3, Cross: 0.6 | Fitness: 28.00 ± 0.00 | Gens: 57.80 | Conv: 100%
# Pop: 10, Mut: 0.3, Cross: 0.8 | Fitness: 28.00 ± 0.00 | Gens: 135.00 | Conv: 100%
